# %%
import pandas as pd
from datetime import datetime
import numpy as np

# %%
df1 = pd.read_csv('./data/CLIENT_191102.tsv', sep = '\t')
df_case = df1.drop(columns = ['EE Provider ID', 'Client Unique ID'])  #EE UID is unique for each case
df_clients = pd.DataFrame(df_case.groupby('Client ID').size()).rename(columns = {0: 'frequency'}) #some client came for more than once
#2364 unique clients
df = df_case.drop(columns = ['EE UID', 'Client Age at Entry', 'Client Age at Exit']).drop_duplicates()
df_clients = pd.merge(df_clients, df, on = 'Client ID', how = 'left')

# %%
df2 = pd.read_csv('./data/DISABILITY_ENTRY_191102.tsv', sep = '\t')
df3 = pd.read_csv('./data/DISABILITY_EXIT_191102.tsv', sep = '\t')

df_diab_entry = df2.rename(columns = {'Disability Determination (Entry)': 'disability_determination_entry', 'Disability Type (Entry)': 'disability_type'})
df_diab_entry = df_diab_entry[df_diab_entry.disability_determination_entry == 'Yes (HUD)'] #filter clients with disability when entry

df_diab_exit = df3.rename(columns = {'Disability Determination (Exit)': 'disability_determination_exit', 'Disability Type (Exit)': 'disability_type'})
df_diab_exit = df_diab_exit[df_diab_exit.disability_determination_exit == 'Yes (HUD)'] #filter clients with disability when exit

df_disable = pd.merge(df_diab_exit,  df_diab_entry, on = ['Client ID', 'disability_type'], how = 'left') #join two dataframe
df_disable = df_disable[['Client ID', 'disability_determination_exit', 'disability_type', 'disability_determination_entry']]
df_disable[df_disable.disability_determination_exit != df_disable.disability_determination_entry] #find out the difference between entry and exit
#data show no information in the change of disability
# Out:
#        Client ID disability_determination_exit  \
# 15015     373323                     Yes (HUD)
# 15906     206895                     Yes (HUD)
# 16759     450723                     Yes (HUD)
# 16784     227895                     Yes (HUD)
# 16785     227895                     Yes (HUD)
# 17859     441891                     Yes (HUD)
# 18216     421698                     Yes (HUD)
# 18275     398931                     Yes (HUD)
# 18640     420015                     Yes (HUD)
# 18832     462367                     Yes (HUD)
# 18912     157439                     Yes (HUD)
# 19651     318721                     Yes (HUD)
# 19885     387424                     Yes (HUD)
# 19892     471672                     Yes (HUD)
# 19942     472732                     Yes (HUD)
# 19943     472732                     Yes (HUD)
# 19944     472732                     Yes (HUD)
# 20056     198791                     Yes (HUD)
# 20057     198791                     Yes (HUD)
# 20058     198791                     Yes (HUD)
# 20213     447807                     Yes (HUD)
# 20335     337991                     Yes (HUD)
# 20336     337991                     Yes (HUD)
# 20337     337991                     Yes (HUD)
# 20338     337991                     Yes (HUD)
# 20339     337991                     Yes (HUD)
# 20340     337991                     Yes (HUD)
# 20438     333756                     Yes (HUD)
# 20693     435077                     Yes (HUD)
# 20791     474632                     Yes (HUD)
# 20868     485227                     Yes (HUD)
# 20869     485227                     Yes (HUD)
# 21041     486478                     Yes (HUD)
# 21116     438055                     Yes (HUD)
# 21139     489122                     Yes (HUD)
# 21306     467749                     Yes (HUD)
# 21308     467749                     Yes (HUD)
# 21479     493799                     Yes (HUD)
# 21779     251488                     Yes (HUD)
# 21788     251488                     Yes (HUD)
# 21851     402258                     Yes (HUD)
# 21863     110973                     Yes (HUD)
# 22133     486416                     Yes (HUD)
# 22134     486416                     Yes (HUD)
# 22223     476246                     Yes (HUD)
# 22258     502250                     Yes (HUD)
# 22259     502250                     Yes (HUD)
# 22499     488547                     Yes (HUD)
# 22500     488547                     Yes (HUD)
# 22526     505061                     Yes (HUD)
# 22583     301301                     Yes (HUD)
# 23106     510454                     Yes (HUD)
# 23321     215700                     Yes (HUD)
# 23385    1000005                     Yes (HUD)
# 25235      88229                     Yes (HUD)
# 28715     277586                     Yes (HUD)
# 28716     277586                     Yes (HUD)
# 28783     385456                     Yes (HUD)
#
#                          disability_type disability_determination_entry
# 15015        Mental Health Problem (HUD)                            NaN
# 15906                Developmental (HUD)                            NaN
# 16759        Mental Health Problem (HUD)                            NaN
# 16784        Mental Health Problem (HUD)                            NaN
# 16785        Mental Health Problem (HUD)                            NaN
# 17859  Both Alcohol and Drug Abuse (HUD)                            NaN
# 18216        Mental Health Problem (HUD)                            NaN
# 18275  Both Alcohol and Drug Abuse (HUD)                            NaN
# 18640                   Drug Abuse (HUD)                            NaN
# 18832                   Drug Abuse (HUD)                            NaN
# 18912                     Physical (HUD)                            NaN
# 19651     Chronic Health Condition (HUD)                            NaN
# 19885                   Drug Abuse (HUD)                            NaN
# 19892        Mental Health Problem (HUD)                            NaN
# 19942  Both Alcohol and Drug Abuse (HUD)                            NaN
# 19943        Mental Health Problem (HUD)                            NaN
# 19944                     Physical (HUD)                            NaN
# 20056     Chronic Health Condition (HUD)                            NaN
# 20057                     HIV/AIDS (HUD)                            NaN
# 20058        Mental Health Problem (HUD)                            NaN
# 20213  Both Alcohol and Drug Abuse (HUD)                            NaN
# 20335     Chronic Health Condition (HUD)                            NaN
# 20336                   Drug Abuse (HUD)                            NaN
# 20337                   Drug Abuse (HUD)                            NaN
# 20338                   Drug Abuse (HUD)                            NaN
# 20339                   Drug Abuse (HUD)                            NaN
# 20340                     HIV/AIDS (HUD)                            NaN
# 20438                Alcohol Abuse (HUD)                            NaN
# 20693        Mental Health Problem (HUD)                            NaN
# 20791                   Drug Abuse (HUD)                            NaN
# 20868                   Drug Abuse (HUD)                            NaN
# 20869        Mental Health Problem (HUD)                            NaN
# 21041        Mental Health Problem (HUD)                            NaN
# 21116        Mental Health Problem (HUD)                            NaN
# 21139                     Physical (HUD)                            NaN
# 21306     Chronic Health Condition (HUD)                            NaN
# 21308                     HIV/AIDS (HUD)                            NaN
# 21479     Chronic Health Condition (HUD)                            NaN
# 21779     Chronic Health Condition (HUD)                            NaN
# 21788                     Physical (HUD)                            NaN
# 21851        Mental Health Problem (HUD)                            NaN
# 21863        Mental Health Problem (HUD)                            NaN
# 22133     Chronic Health Condition (HUD)                            NaN
# 22134                     HIV/AIDS (HUD)                            NaN
# 22223        Mental Health Problem (HUD)                            NaN
# 22258        Mental Health Problem (HUD)                            NaN
# 22259                     Physical (HUD)                            NaN
# 22499                Alcohol Abuse (HUD)                            NaN
# 22500        Mental Health Problem (HUD)                            NaN
# 22526                Alcohol Abuse (HUD)                            NaN
# 22583        Mental Health Problem (HUD)                            NaN
# 23106                     Physical (HUD)                            NaN
# 23321                   Drug Abuse (HUD)                            NaN
# 23385                Alcohol Abuse (HUD)                            NaN
# 25235        Mental Health Problem (HUD)                            NaN
# 28715        Mental Health Problem (HUD)                            NaN
# 28716        Mental Health Problem (HUD)                            NaN
# 28783     Chronic Health Condition (HUD)                            NaN

# %%
df_disable_indicator = pd.DataFrame(df_diab_exit.groupby('Client ID').size()).rename(columns = {0: 'disability_size'})
df_clients = pd.merge(df_clients, df_disable_indicator, on = 'Client ID', how = 'left')
df_clients = df_clients.fillna(0)
df_clients['disability'] = round(df_clients['disability_size']/df_clients['frequency'])
df_clients = df_clients.drop(columns = ['disability_size'])

# %%
df5 = pd.read_csv('./data/EE_UDES_191102.tsv', sep = '\t')

df_udes = df5[['Client ID', 'Prior Living Situation(43)', 
               'Total number of months homeless on the street, in ES or SH in the past three years(5168)', 
              'Housing Status(2703)', 'Domestic violence victim/survivor(341)']]
df_udes = df_udes.rename(columns = {'Prior Living Situation(43)': 'prior_living_situation', 
               'Total number of months homeless on the street, in ES or SH in the past three years(5168)': 'months_on_street', 
              'Housing Status(2703)': 'housing_status', 'Domestic violence victim/survivor(341)': 'domestic_violence'})
df_udes = df_udes.drop_duplicates().dropna()
df_udes['prior_living_situation'] = df_udes['prior_living_situation'].replace('Data not collected (HUD)', np.nan).replace('Other (HUD)', np.nan)
df_udes['months_on_street'] = df_udes['months_on_street'].replace(["Client doesn't know (HUD)", 'Client refused (HUD)', "Data not collected (HUD)"], np.nan)

# %%
df_udes_sub = df_udes[['Client ID', 'domestic_violence']]
df_clients = pd.merge(df_clients, df_udes_sub, on = 'Client ID', how = 'left')

# %%
df_entry_exit = pd.read_csv('./data/ENTRY_EXIT_191102.tsv', sep = '\t')
df_entry_exit = df_entry_exit[['EE UID', 'Client ID', 'Entry Date', 'Exit Date', 'Destination', 'Reason for Leaving']]
df_entry_exit['Entry Date'] = pd.to_datetime(df_entry_exit['Entry Date'], format = '%m/%d/%Y')
df_entry_exit['Exit Date'] = pd.to_datetime(df_entry_exit['Exit Date'], format = '%m/%d/%Y')
df_entry_exit['Exit Date'] = df_entry_exit['Exit Date'].replace(np.datetime64('NaT'), datetime.now())
df_entry_exit['Period'] = (df_entry_exit['Exit Date'] - df_entry_exit['Entry Date']).dt.days

# %%
df = df_entry_exit.groupby('Client ID').mean().drop(columns = ['EE UID'])
df_clients = pd.merge(df_clients, df, on = 'Client ID', how = 'left')

# %%
df6 = pd.read_csv('./data/HEALTH_INS_ENTRY_191102.tsv', sep = '\t')
df7 = pd.read_csv('./data/HEALTH_INS_EXIT_191102.tsv', sep = '\t')

# %%
l = [] 
for Ins_type, sub_df in df6.groupby('Health Insurance Type (Entry)'):
    l.append(Ins_type)
print(l)

ls = []
for Ins_type, sub_df in df7.groupby('Health Insurance Type (Exit)'):
    ls.append(Ins_type)
print(ls)
l == ls
#type of health insurance are same
# Out:
# ['Employer - Provided Health Insurance', 'Health Insurance obtained through COBRA', 'Indian Health Services Program', 'MEDICAID', 'MEDICARE', 'Other', 'Private Pay Health Insurance', "State Children's Health Insurance Program", 'State Health Insurance for Adults', "Veteran's Administration (VA) Medical Services"]
# ['Employer - Provided Health Insurance', 'Health Insurance obtained through COBRA', 'Indian Health Services Program', 'MEDICAID', 'MEDICARE', 'Other', 'Private Pay Health Insurance', "State Children's Health Insurance Program", 'State Health Insurance for Adults', "Veteran's Administration (VA) Medical Services"]
# True

# %%
df6s = df6[df6['Covered (Entry)'] == 'Yes'].rename(columns = {'Health Insurance Type (Entry)': 'health_insurance_type'})
df6s = df6s[['Client ID', 'Covered (Entry)', 'health_insurance_type']]
df7s = df7[df7['Covered (Exit)'] == 'Yes'].rename(columns = {'Health Insurance Type (Exit)': 'health_insurance_type'})
df7s = df7s[['Client ID', 'Covered (Exit)', 'health_insurance_type']]
df_healthins = pd.merge(df7s, df6s, on = ['Client ID', 'health_insurance_type'], how = 'inner').drop_duplicates()
df_healthins[df_healthins['Covered (Exit)'] != df_healthins['Covered (Entry)']]
#no difference in health insurance covered when entry and exit
# Out:
# Empty DataFrame
# Columns: [Client ID, Covered (Exit), health_insurance_type, Covered (Entry)]
# Index: []

# %%
df_healthins_types = pd.DataFrame(df_healthins.groupby('Client ID').size()).rename(columns = {0: 'healthins_types'})
df_clients = pd.merge(df_clients, df_healthins_types, on = ['Client ID'], how = 'left')  #add health insurance

# %%
df8 = pd.read_csv('./data/INCOME_ENTRY_191102.tsv', sep = '\t')
df8 = df8[['Client ID', 'Receiving Income (Entry)', 'Income Source (Entry)', 'Monthly Amount (Entry)']]
df_income_entry = pd.DataFrame(df8.groupby('Client ID', as_index=False).mean())
df9 = pd.read_csv('./data/INCOME_EXIT_191102.tsv', sep = '\t')
df9 = df9[['Client ID', 'ReceivingIncome (Exit)', 'Source of Income (Exit)', 'Monthly Amount (Exit)']]
df_income_exit = pd.DataFrame(df9.groupby('Client ID', as_index=False).mean())

# %%
df_income = pd.merge(df_income_exit, df_income_entry, on = ['Client ID'], how = 'left')
df_income = df_income.dropna(thresh = 2)
df_income.fillna(0, inplace = True)
df_income['changes'] = df_income['Monthly Amount (Exit)'] - df_income['Monthly Amount (Entry)']
df_clients = pd.merge(df_clients, df_income, on = ['Client ID'], how = 'left') #add income

# %%
df_case
# Out:
#       EE UID  Client ID  Client Age at Entry  Client Age at Exit  \
# 0     687901     397941                 60.0                61.0
# 1     687902     130335                 48.0                48.0
# 2     687903     188933                 42.0                42.0
# 3     687904     168290                 57.0                57.0
# 4     687905     123122                 51.0                51.0
# 5     687907     363382                 30.0                30.0
# 6     687909     165730                 51.0                51.0
# 7     687911     291392                 56.0                56.0
# 8     687912     359808                 60.0                60.0
# 9     687913     385539                 59.0                59.0
# 10    687914     360237                 51.0                51.0
# 11    687951     403745                 31.0                31.0
# 12    687967     404039                 44.0                44.0
# 13    687968     381869                 75.0                75.0
# 14    687969     397313                 40.0                40.0
# 15    687970     185069                 42.0                42.0
# 16    687973     399028                 51.0                52.0
# 17    687974     361024                 50.0                50.0
# 18    687975     324453                 45.0                45.0
# 19    687982     395548                 55.0                55.0
# 20    688348     393111                 49.0                49.0
# 21    688349     379956                 50.0                50.0
# 22    688350     397202                 26.0                26.0
# 23    688352     251488                 49.0                49.0
# 24    688353     395541                 61.0                61.0
# 25    688357     381870                 53.0                53.0
# 26    688359     392383                 53.0                53.0
# 27    688361     318262                 36.0                36.0
# 28    688362     381470                 58.0                58.0
# 29    688363     309651                 26.0                26.0
# ...      ...        ...                  ...                 ...
# 5269  676330     367659                 46.0                46.0
# 5270  676331     401494                 19.0                20.0
# 5271  676332     401763                 53.0                53.0
# 5272  676333     224787                 65.0                65.0
# 5273  676334     400077                 41.0                42.0
# 5274  678116     384147                 59.0                59.0
# 5275  680007     403049                 63.0                63.0
# 5276  680008     399904                 58.0                58.0
# 5277  680009     403050                 23.0                23.0
# 5278  680010     403483                 46.0                47.0
# 5279  680636     281794                 44.0                44.0
# 5280  680643     404217                 25.0                25.0
# 5281  680644     225552                 51.0                51.0
# 5282  680645     341407                 26.0                26.0
# 5283  680646     390302                 46.0                46.0
# 5284  546828     363078                 62.0                63.0
# 5285  594343     291392                 55.0                56.0
# 5286  594345     382261                 49.0                50.0
# 5287  614812     359808                 59.0                60.0
# 5288  614814     385539                 58.0                58.0
# 5289  624055     373730                 26.0                26.0
# 5290  643552     393036                 63.0                63.0
# 5291  643553     360237                 50.0                51.0
# 5292  651504     385539                 58.0                59.0
# 5293  658081     111217                 54.0                54.0
# 5294  668873     370291                 68.0                68.0
# 5295  670063     175198                 61.0                61.0
# 5296  676326     401978                 54.0                54.0
# 5297  678129     401495                 49.0                50.0
# 5298  680011     403361                 52.0                52.0
#
#      Client Gender                     Client Primary Race  \
# 0           Female                             White (HUD)
# 1           Female         Black or African American (HUD)
# 2           Female         Black or African American (HUD)
# 3             Male                             White (HUD)
# 4             Male                             White (HUD)
# 5             Male         Black or African American (HUD)
# 6             Male         Black or African American (HUD)
# 7             Male         Black or African American (HUD)
# 8             Male         Black or African American (HUD)
# 9             Male         Black or African American (HUD)
# 10            Male         Black or African American (HUD)
# 11            Male         Black or African American (HUD)
# 12          Female         Black or African American (HUD)
# 13          Female                             White (HUD)
# 14          Female         Black or African American (HUD)
# 15          Female         Black or African American (HUD)
# 16          Female                             White (HUD)
# 17          Female         Black or African American (HUD)
# 18            Male         Black or African American (HUD)
# 19          Female         Black or African American (HUD)
# 20            Male                             White (HUD)
# 21            Male         Black or African American (HUD)
# 22            Male         Black or African American (HUD)
# 23            Male         Black or African American (HUD)
# 24            Male         Black or African American (HUD)
# 25            Male                             White (HUD)
# 26            Male         Black or African American (HUD)
# 27            Male         Black or African American (HUD)
# 28            Male         Black or African American (HUD)
# 29            Male         Black or African American (HUD)
# ...            ...                                     ...
# 5269        Female         Black or African American (HUD)
# 5270          Male         Black or African American (HUD)
# 5271        Female                             White (HUD)
# 5272          Male         Black or African American (HUD)
# 5273        Female                             White (HUD)
# 5274          Male                             White (HUD)
# 5275          Male         Black or African American (HUD)
# 5276          Male         Black or African American (HUD)
# 5277          Male  American Indian or Alaska Native (HUD)
# 5278          Male         Black or African American (HUD)
# 5279          Male                             White (HUD)
# 5280          Male         Black or African American (HUD)
# 5281          Male         Black or African American (HUD)
# 5282          Male         Black or African American (HUD)
# 5283        Female         Black or African American (HUD)
# 5284          Male         Black or African American (HUD)
# 5285          Male         Black or African American (HUD)
# 5286          Male         Black or African American (HUD)
# 5287          Male         Black or African American (HUD)
# 5288          Male         Black or African American (HUD)
# 5289          Male         Black or African American (HUD)
# 5290          Male         Black or African American (HUD)
# 5291          Male         Black or African American (HUD)
# 5292          Male         Black or African American (HUD)
# 5293          Male         Black or African American (HUD)
# 5294          Male         Black or African American (HUD)
# 5295          Male         Black or African American (HUD)
# 5296          Male                             White (HUD)
# 5297          Male         Black or African American (HUD)
# 5298          Male         Black or African American (HUD)
#
#                    Client Ethnicity Client Veteran Status
# 0     Non-Hispanic/Non-Latino (HUD)              No (HUD)
# 1     Non-Hispanic/Non-Latino (HUD)              No (HUD)
# 2     Non-Hispanic/Non-Latino (HUD)              No (HUD)
# 3             Hispanic/Latino (HUD)              No (HUD)
# 4     Non-Hispanic/Non-Latino (HUD)              No (HUD)
# 5     Non-Hispanic/Non-Latino (HUD)              No (HUD)
# 6     Non-Hispanic/Non-Latino (HUD)              No (HUD)
# 7     Non-Hispanic/Non-Latino (HUD)             Yes (HUD)
# 8     Non-Hispanic/Non-Latino (HUD)             Yes (HUD)
# 9     Non-Hispanic/Non-Latino (HUD)             Yes (HUD)
# 10    Non-Hispanic/Non-Latino (HUD)             Yes (HUD)
# 11    Non-Hispanic/Non-Latino (HUD)              No (HUD)
# 12    Non-Hispanic/Non-Latino (HUD)              No (HUD)
# 13    Non-Hispanic/Non-Latino (HUD)              No (HUD)
# 14    Non-Hispanic/Non-Latino (HUD)              No (HUD)
# 15    Non-Hispanic/Non-Latino (HUD)              No (HUD)
# 16    Non-Hispanic/Non-Latino (HUD)              No (HUD)
# 17    Non-Hispanic/Non-Latino (HUD)              No (HUD)
# 18    Non-Hispanic/Non-Latino (HUD)              No (HUD)
# 19    Non-Hispanic/Non-Latino (HUD)              No (HUD)
# 20    Non-Hispanic/Non-Latino (HUD)              No (HUD)
# 21    Non-Hispanic/Non-Latino (HUD)              No (HUD)
# 22    Non-Hispanic/Non-Latino (HUD)              No (HUD)
# 23    Non-Hispanic/Non-Latino (HUD)              No (HUD)
# 24    Non-Hispanic/Non-Latino (HUD)              No (HUD)
# 25    Non-Hispanic/Non-Latino (HUD)              No (HUD)
# 26    Non-Hispanic/Non-Latino (HUD)              No (HUD)
# 27    Non-Hispanic/Non-Latino (HUD)              No (HUD)
# 28    Non-Hispanic/Non-Latino (HUD)             Yes (HUD)
# 29    Non-Hispanic/Non-Latino (HUD)              No (HUD)
# ...                             ...                   ...
# 5269  Non-Hispanic/Non-Latino (HUD)              No (HUD)
# 5270  Non-Hispanic/Non-Latino (HUD)              No (HUD)
# 5271  Non-Hispanic/Non-Latino (HUD)              No (HUD)
# 5272  Non-Hispanic/Non-Latino (HUD)              No (HUD)
# 5273       Data not collected (HUD)              No (HUD)
# 5274  Non-Hispanic/Non-Latino (HUD)              No (HUD)
# 5275  Non-Hispanic/Non-Latino (HUD)              No (HUD)
# 5276  Non-Hispanic/Non-Latino (HUD)              No (HUD)
# 5277  Non-Hispanic/Non-Latino (HUD)              No (HUD)
# 5278  Non-Hispanic/Non-Latino (HUD)              No (HUD)
# 5279  Non-Hispanic/Non-Latino (HUD)              No (HUD)
# 5280  Non-Hispanic/Non-Latino (HUD)              No (HUD)
# 5281  Non-Hispanic/Non-Latino (HUD)              No (HUD)
# 5282  Non-Hispanic/Non-Latino (HUD)              No (HUD)
# 5283  Non-Hispanic/Non-Latino (HUD)              No (HUD)
# 5284  Non-Hispanic/Non-Latino (HUD)             Yes (HUD)
# 5285  Non-Hispanic/Non-Latino (HUD)             Yes (HUD)
# 5286  Non-Hispanic/Non-Latino (HUD)             Yes (HUD)
# 5287  Non-Hispanic/Non-Latino (HUD)             Yes (HUD)
# 5288  Non-Hispanic/Non-Latino (HUD)             Yes (HUD)
# 5289  Non-Hispanic/Non-Latino (HUD)             Yes (HUD)
# 5290  Non-Hispanic/Non-Latino (HUD)             Yes (HUD)
# 5291  Non-Hispanic/Non-Latino (HUD)             Yes (HUD)
# 5292  Non-Hispanic/Non-Latino (HUD)             Yes (HUD)
# 5293  Non-Hispanic/Non-Latino (HUD)             Yes (HUD)
# 5294  Non-Hispanic/Non-Latino (HUD)             Yes (HUD)
# 5295  Non-Hispanic/Non-Latino (HUD)             Yes (HUD)
# 5296  Non-Hispanic/Non-Latino (HUD)             Yes (HUD)
# 5297  Non-Hispanic/Non-Latino (HUD)             Yes (HUD)
# 5298  Non-Hispanic/Non-Latino (HUD)             Yes (HUD)
#
# [5299 rows x 8 columns]

# %%
df_udess = df5[['EE UID', 'Client ID', 'Prior Living Situation(43)', 
               'Total number of months homeless on the street, in ES or SH in the past three years(5168)', 
              'Housing Status(2703)', 'Domestic violence victim/survivor(341)', 'Does the client have a disabling condition?(1935)',
               'Covered by Health Insurance(4376)']]
df_udess = df_udess.rename(columns = {'Prior Living Situation(43)': 'prior_living_situation', 
               'Total number of months homeless on the street, in ES or SH in the past three years(5168)': 'months_on_street', 
              'Housing Status(2703)': 'housing_status', 'Domestic violence victim/survivor(341)': 'domestic_violence', 
                                      'Does the client have a disabling condition?(1935)': 'disabiltiy', 'Covered by Health Insurance(4376)': 'health_insurance'})

# %%
df_case = pd.merge(df_case, df_udess, on = ['EE UID', 'Client ID'], how = 'left')

# %%
df0 = df_clients.drop_duplicates()
#df0.groupby('Client ID').size()
df0[df0['Client ID'] == 2054]
# Out:
#    Client ID  frequency Client Gender Client Primary Race  \
# 6       2054         22        Female         White (HUD)
# 7       2054         22        Female         White (HUD)
#
#                 Client Ethnicity Client Veteran Status  disability  \
# 6  Non-Hispanic/Non-Latino (HUD)              No (HUD)         3.0
# 7  Non-Hispanic/Non-Latino (HUD)              No (HUD)         3.0
#
#                   housing_status domestic_violence     Period  \
# 6    Category 1 - Homeless (HUD)          No (HUD)  45.818182
# 7  At-risk of homelessness (HUD)          No (HUD)  45.818182
#
#    healthins_types  Monthly Amount (Exit)  Monthly Amount (Entry)   changes
# 6              1.0             522.369231              524.666667 -2.297436
# 7              1.0             522.369231              524.666667 -2.297436
